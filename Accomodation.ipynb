# %%
import pandas as pd
import numpy as np

# %%
calendar = pd.read_csv('C:/Users/Subhadri/Desktop/Data Science - Term 1/EDA/Assignment 2/calendar.csv')
print(calendar.shape)
calendar.head()
# Out:
# (4351530, 4)
#    listing_id        date available   price
# 0      635756  2019-11-14         t  $67.00
# 1      292285  2019-11-14         f     NaN
# 2      292285  2019-11-13         f     NaN
# 3      292285  2019-11-12         f     NaN
# 4      292285  2019-11-11         f     NaN

# %%
listings = pd.read_csv('C:/Users/Subhadri/Desktop/Data Science - Term 1/EDA/Assignment 2/listings.csv')
print(listings.shape)
listings.head()
# Out:
# (11922, 96)
#       id                         listing_url       scrape_id last_scraped  \
# 0      6      https://www.airbnb.com/rooms/6  20181115100559   2018-11-15
# 1   5570   https://www.airbnb.com/rooms/5570  20181115100559   2018-11-15
# 2   8095   https://www.airbnb.com/rooms/8095  20181115100559   2018-11-15
# 3  39516  https://www.airbnb.com/rooms/39516  20181115100559   2018-11-15
# 4  45429  https://www.airbnb.com/rooms/45429  20181115100559   2018-11-15
#
#                                              name  \
# 0  Large Craftsmen w/ yard ~ Perfect for families
# 1                   Ocean front condo on the sand
# 2                            Sunset Cliffs Studio
# 3                 Art Studio Retreat/Rustic Cabin
# 4                 OB cottage SD--view on waterway
#
#                                              summary  \
# 0  Our Beautiful Craftsmen house has all the mode...
# 1  Missionbeachretreat.   Great Ocean Front Condo...
# ...

# %%
listings_brief = pd.read_csv('C:/Users/Subhadri/Desktop/Data Science - Term 1/EDA/Assignment 2/listings_brief.csv')
print(listings_brief.shape)
listings_brief.head()
# Out:
# (11922, 16)
#       id                                            name  host_id  \
# 0      6  Large Craftsmen w/ yard ~ Perfect for families       29
# 1   5570                   Ocean front condo on the sand     8435
# 2   8095                            Sunset Cliffs Studio      270
# 3  39516                 Art Studio Retreat/Rustic Cabin   169649
# 4  45429                 OB cottage SD--view on waterway   197919
#
#                            host_name  neighbourhood_group neighbourhood  \
# 0                               Sara                  NaN   North Hills
# 1  Jef Karchin'S MISSIONBEACHRETREAT                  NaN   Mission Bay
# 2                              Marin                  NaN   Ocean Beach
# 3                    Chris  And Jean                  NaN   North Hills
# 4                            Melissa                  NaN   Loma Portal
#
#     latitude   longitude        room_type  price  minimum_nights  \
# ...

# %%
neighbourhoods = pd.read_csv('C:/Users/Subhadri/Desktop/Data Science - Term 1/EDA/Assignment 2/neighbourhoods.csv')
print(neighbourhoods.shape)
neighbourhoods.head()
# Out:
# (108, 2)
#    neighbourhood_group                neighbourhood
# 0                  NaN               Allied Gardens
# 1                  NaN                   Alta Vista
# 2                  NaN  Amphitheater And Water Park
# 3                  NaN                  Balboa Park
# 4                  NaN                  Bario Logan

# %%
reviews = pd.read_csv('C:/Users/Subhadri/Desktop/Data Science - Term 1/EDA/Assignment 2/reviews.csv')
print(reviews.shape)
reviews.head()
# Out:
# (344404, 6)
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0           6        8  2008-06-22          415      Terrence
# 1           6     4383  2009-06-22         3762     Christine
# 2           6  1722383  2012-07-16      1864778          Hieu
# 3           6  5595071  2013-07-07       117966        Daryna
# 4           6  5631156  2013-07-08      6563815        Mathew
#
#                                             comments
# 0  Sara is an awesome hostess.  She was very cons...
# 1  My stay at “Craftsmen” was wonderful!  Sara wa...
# 2  This was my first time using Airbnb and Sara m...
# 3  Sara was a very pleasant host! Reservation was...
# 4  Sara was such an amazing hostess! My girlfrien...

# %%
reviews_brief = pd.read_csv('C:/Users/Subhadri/Desktop/Data Science - Term 1/EDA/Assignment 2/reviews_brief.csv')
print(reviews_brief.shape)
reviews_brief.head()
# Out:
# (344404, 2)
#    listing_id        date
# 0           6  2008-06-22
# 1           6  2009-06-22
# 2           6  2012-07-16
# 3           6  2013-07-07
# 4           6  2013-07-08

# %%
calendar['date'] = pd.to_datetime(calendar['date'], format = "%Y-%m-%d")
calendar['day'] = calendar['date'].dt.day
calendar['month'] = calendar['date'].dt.month
calendar['Year'] = calendar['date'].dt.year
calendar['day_name'] = calendar['date'].dt.strftime('%A')
calendar['month_name'] = calendar['date'].dt.strftime('%B')

# %%
calendar['available'].replace('t','1', inplace = True)
calendar['available'].replace('f','0', inplace =True)

# %%
calendar.head()
# Out:
#    listing_id       date available   price  day  month  Year   day_name  \
# 0      635756 2019-11-14         1  $67.00   14     11  2019   Thursday
# 1      292285 2019-11-14         0     NaN   14     11  2019   Thursday
# 2      292285 2019-11-13         0     NaN   13     11  2019  Wednesday
# 3      292285 2019-11-12         0     NaN   12     11  2019    Tuesday
# 4      292285 2019-11-11         0     NaN   11     11  2019     Monday
#
#   month_name
# 0   November
# 1   November
# 2   November
# 3   November
# 4   November

# %%
# count of Listing based on each month.

a_listing = calendar.groupby(['month_name'])['listing_id'].count().sort_values(ascending=False).to_frame().reset_index()
a_listing = a_listing.rename(columns = {'month_name' : 'Months','listing_id' : 'Number of Listings'})
a_listing
# Out:
#        Months  Number of Listings
# 0     October              369582
# 1         May              369582
# 2       March              369582
# 3        July              369582
# 4     January              369582
# 5    December              369582
# 6      August              369582
# 7   September              357660
# 8    November              357660
# 9        June              357660
# 10      April              357660
# 11   February              333816

# %%
# we will use autopct to indicate percent lables on pie chart

from matplotlib import pyplot as plt
plt.pie(a_listing['Number of Listings'], labels = a_listing['Months'], autopct = '%.2f%%', pctdistance = 0.6,radius=3)
plt.rcParams['font.size'] = 15
plt.show()

# %%
# Number of listings were published in every Year.

b_listing = calendar.groupby(['Year'])['listing_id'].count().sort_values(ascending=False).to_frame().reset_index()
b_listing = b_listing.rename(columns = {'listing_id' : 'Number of Listings'})
b_listing
# Out:
#    Year  Number of Listings
# 0  2019             3791250
# 1  2018              560280

# %%
from matplotlib import pyplot as plt
plt.pie(b_listing['Number of Listings'], labels = b_listing['Year'], autopct = '%.2f%%', pctdistance = 0.6,radius=3)
plt.rcParams['font.size'] = 15
plt.show()

# %%
# Number of listings were published in every Year and in each month.

c_listing = calendar.groupby(['Year','month_name'])['listing_id'].count().to_frame().reset_index()
c_listing = c_listing.rename(columns = {'month_name' : 'Month','listing_id' : 'Number of Listings'})
c_listing
# Out:
#     Year      Month  Number of Listings
# 0   2018   December              369582
# 1   2018   November              190698
# 2   2019      April              357660
# 3   2019     August              369582
# 4   2019   February              333816
# 5   2019    January              369582
# 6   2019       July              369582
# 7   2019       June              357660
# 8   2019      March              369582
# 9   2019        May              369582
# 10  2019   November              166962
# 11  2019    October              369582
# 12  2019  September              357660

# %%
import seaborn as sb
plt.figure(figsize = (12,8))
sb.countplot(y = "month_name", hue = "Year", data = calendar)

# %%
listings_merge = pd.merge(listings,listings_brief,left_on = "id",right_on = "id")
listings_merge.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0      6      https://www.airbnb.com/rooms/6  20181115100559   2018-11-15
# 1   5570   https://www.airbnb.com/rooms/5570  20181115100559   2018-11-15
# 2   8095   https://www.airbnb.com/rooms/8095  20181115100559   2018-11-15
# 3  39516  https://www.airbnb.com/rooms/39516  20181115100559   2018-11-15
# 4  45429  https://www.airbnb.com/rooms/45429  20181115100559   2018-11-15
#
#                                            name_x  \
# 0  Large Craftsmen w/ yard ~ Perfect for families
# 1                   Ocean front condo on the sand
# 2                            Sunset Cliffs Studio
# 3                 Art Studio Retreat/Rustic Cabin
# 4                 OB cottage SD--view on waterway
#
#                                              summary  \
# 0  Our Beautiful Craftsmen house has all the mode...
# 1  Missionbeachretreat.   Great Ocean Front Condo...
# ...

# %%
# Top 5 hosts where the maximum number of listings are published

d_listing = listings_merge.groupby(['host_name_x'])['id'].count().sort_values(ascending=False).to_frame().reset_index().head(10)
d_listing = d_listing.rename(columns = {'host_name_x' : 'Host Name','id' : 'Count'})
d_listing
# Out:
#                   Host Name  Count
# 0                 SeaBreeze    161
# 1         710 Beach Rentals    133
# 2                      John    111
# 3                   Michael    101
# 4                    Sonder     96
# 5                     Nadia     79
# 6                 Christine     69
# 7                     David     68
# 8  Bluewater Vacation Homes     61
# 9                    Nancys     58

# %%
plt.figure(figsize = (8,4))
sb.barplot("Count", y="Host Name", data=d_listing ,palette="Blues_d")
plt.title("Top 10 Hosts")
# Out:
# Text(0.5, 1.0, 'Top 10 Hosts')

# %%
# Number of incorrect locations

e_listing = listings_merge['is_location_exact'].value_counts().to_frame().reset_index()
e_listing['index'] = e_listing['index'].replace('f','No').replace('t', 'Yes')
e_listing
# Out:
#   index  is_location_exact
# 0   Yes               9307
# 1    No               2615

# %%
sb.barplot("is_location_exact", y = "index", data = e_listing ,palette = "muted")
plt.ylabel('Exact Location (Yes/No)')
plt.xlabel('Count')
plt.title("Exact Location (Yes/No)")
# Out:
# Text(0.5, 1.0, 'Exact Location (Yes/No)')

# %%
# Which property type have how many listings

f_listing = listings_merge.groupby(['property_type'])['id'].count().sort_values().to_frame().reset_index()
f_listing
# Out:
#                     property_type    id
# 0                     Earth house     1
# 1   Shepherd's hut (U.K., France)     1
# 2                           Igloo     1
# 3                      Condohotel     1
# 4          Casa particular (Cuba)     1
# 5                        Campsite     1
# 6                       Treehouse     2
# 7                            Cave     2
# 8                             Bus     2
# 9                          Castle     3
# 10                     Aparthotel     7
# 11                           Tent     9
# 12                          Cabin    10
# 13                          Hotel    13
# 14                     Tiny house    20
# 15                 Boutique hotel    26
# 16                         Resort    37
# 17              Bed and breakfast    38
# 18                          Other    49
# 19                      Camper/RV    52
# 20                           Boat    54
# 21                          Villa    63
# ...

# %%
sb.set(rc = {'figure.figsize':(11.7,8.27)})
sb.barplot("id", y = "property_type", data = f_listing, palette = "muted")
plt.ylabel('Count')
plt.xlabel('Property Type')
plt.title("Property wise Listing")
# Out:
# Text(0.5, 1.0, 'Property wise Listing')

# %%
# Number of listings for each Room Type 

g_listing = listings_merge.groupby(['room_type_x'])['id'].count().to_frame().reset_index()
g_listing
# Out:
#        room_type_x    id
# 0  Entire home/apt  8304
# 1     Private room  3426
# 2      Shared room   192

# %%
sb.set(rc = {'figure.figsize':(7,5)})
sb.barplot("id", y = "room_type_x", data = g_listing, palette = "BuGn_r")
plt.ylabel('Count')
plt.xlabel('Room Type')
plt.title("Room wise Listing")
# Out:
# Text(0.5, 1.0, 'Room wise Listing')

# %%
# Number of accomodations in each property

sb.set(rc = {'figure.figsize':(12,9)})
sb.barplot("accommodates", y = "property_type", data = listings_merge, palette = "muted")
plt.title("Number of accomodations in each property")
# Out:
# Text(0.5, 1.0, 'Number of accomodations in each property')

# %%
# Number of bathrooms in each property.

sb.set(rc = {'figure.figsize':(12,9)})
sb.barplot("bathrooms", y = "property_type", data = listings_merge, palette = "dark")
plt.title("bathrooms in each property")
# Out:
# Text(0.5, 1.0, 'bathrooms in each property')

# %%
# Number of bedrooms in each property.

sb.set(rc = {'figure.figsize':(12,9)})
sb.barplot("bedrooms", y = "property_type", data = listings_merge, palette = "colorblind")
plt.title("bedrooms in each property")
# Out:
# Text(0.5, 1.0, 'bedrooms in each property')

# %%
# Average price (in Dollars) of each property 

i_listing = listings_merge.groupby(['property_type'])['price_y'].mean().sort_values(ascending=False).reset_index()
i_listing
# Out:
#                     property_type     price_y
# 0                           Villa  834.698413
# 1                          Castle  783.333333
# 2                            Boat  517.333333
# 3                      Condohotel  275.000000
# 4                           House  267.684299
# 5                          Resort  251.243243
# 6                           Hotel  240.153846
# 7                     Condominium  233.503890
# 8                  Boutique hotel  213.269231
# 9                      Aparthotel  205.285714
# 10                            Bus  201.500000
# 11                      Townhouse  198.006015
# 12                           Loft  178.774468
# 13                          Other  178.020408
# 14                        Cottage  171.688312
# 15              Bed and breakfast  164.052632
# 16             Serviced apartment  162.505747
# 17                      Apartment  160.241224
# 18                       Bungalow  158.784053
# ...

# %%
sb.barplot("price_y", y = "property_type", data = i_listing, palette = "Blues_d")
plt.title("Average price (in Dollars) of each property ")
# Out:
# Text(0.5, 1.0, 'Average price (in Dollars) of each property ')

# %%
# Average Rating of each property type

j_listing = listings_merge.groupby(['property_type'])['review_scores_rating'].mean().sort_values(ascending=False).to_frame()
j_listing = j_listing[j_listing.review_scores_rating.notnull()].reset_index()
j_listing
# Out:
#          property_type  review_scores_rating
# 0           Aparthotel            100.000000
# 1           Condohotel            100.000000
# 2                Igloo            100.000000
# 3             Campsite            100.000000
# 4               Resort             99.200000
# 5               Castle             99.000000
# 6                 Boat             97.944444
# 7                 Tent             97.833333
# 8                Hotel             97.714286
# 9          Guest suite             97.284916
# 10          Guesthouse             97.044974
# 11          Tiny house             96.687500
# 12            Bungalow             96.487365
# 13           Townhouse             96.324910
# 14                Loft             95.773399
# 15               Villa             95.745098
# 16               House             95.652187
# 17                Cave             95.500000
# 18         Condominium             95.086093
# 19  Serviced apartment             95.056604
# ...

# %%
# Number of properties lie in each cancellation policy.

k_listing = listings_merge.groupby(['cancellation_policy'])['property_type'].count().reset_index()
k_listing
# Out:
#            cancellation_policy  property_type
# 0                     flexible           3090
# 1                     moderate           3087
# 2                       strict             69
# 3  strict_14_with_grace_period           5060
# 4              super_strict_30            175
# 5              super_strict_60            441

# %%
explode = (0,0,0,0,0,0)
plt.pie(k_listing['property_type'], labels = k_listing['cancellation_policy'], autopct = '%.2f%%', pctdistance = 0.8, explode = explode)
centre_circle = plt.Circle((0,0),0.50, fc = 'white')

# gcf = get current figure
# gca = get current axis

fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.axis('equal')
plt.title("Cancellation Policy")

plt.show()

# %%
sb.barplot("cancellation_policy", y = "property_type", data = k_listing)
plt.title("property lies in each cancellation policy")
# Out:
# Text(0.5, 1.0, 'property lies in each cancellation policy')

# %%
# Reviews per month for each property type

sb.stripplot(listings_merge['reviews_per_month_x'], listings_merge['property_type'], jitter = 0.3, size = 5)
plt.show()
